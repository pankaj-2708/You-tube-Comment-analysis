# %%
import pandas as pd

# %%
df=pd.read_csv("runs.csv")

# %%
df[~df['params.model'].isnull()]
# Out:
#                               run_id       experiment_id    status  \
# 1   ff50171cbd6d47ffaaf9c4e8d9f41fcd  593622924682077431  FINISHED
# 5   283bd5b1725e49549dc40dd22535707f  593622924682077431  FINISHED
# 34  62ef59f75f424c8ebe10a17fa8a89371  593622924682077431  FINISHED
# 38  86dc7be6be0f4abead3e76dfd90d2ce0  593622924682077431  FINISHED
#
#                                          artifact_uri  \
# 1   s3://pankaj-maulekhi-mlflow/593622924682077431...
# 5   s3://pankaj-maulekhi-mlflow/593622924682077431...
# 34  s3://pankaj-maulekhi-mlflow/593622924682077431...
# 38  s3://pankaj-maulekhi-mlflow/593622924682077431...
#
#                           start_time                          end_time  \
# 1   2025-10-03 17:32:58.762000+00:00  2025-10-03 17:36:20.375000+00:00
# 5   2025-10-03 16:31:32.224000+00:00  2025-10-03 16:33:37.683000+00:00
# 34  2025-10-03 14:01:38.175000+00:00  2025-10-03 14:02:26.279000+00:00
# ...
